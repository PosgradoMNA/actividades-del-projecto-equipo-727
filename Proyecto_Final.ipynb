# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-727/blob/main/Proyecto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto Final**
# **Integrantes**:
# 1.   Fabian Munoz
# 2.   Maria Nelly Porras
#
# **Descripción**:
# Permitiría el acceso a la prestación a todos aquellos desempleados del sector formal, independientemente de la situación que haya originado el episodio de desempleo; otorgando un piso de beneficio equivalente un mes de salario mínimo, hasta por seis meses.

# %% [markdown]
# 1. El nombre del conjunto de datos: s**olicitudes-seguro-de-desempleo**
# 2. El nombre de la organización que lo generó: **Gobierno de la Cidudad de Mexico**
# 3. El enlace de Internet donde se puede descargar la base de datos: **https://datos.cdmx.gob.mx/dataset/solicitudes-seguro-de-desempleo**
# 4. Describe el conjunto de datos: **Base de datos con historica haste Enero 2021 con 20,788 solicitudes de ingreso al programa. Cuenta con atributos categoricos relacionados con geografia y nivel de estudios.**
# 5. Enumera 8 (ocho) preguntas de investigación que podría responder con estos datos:
#
# a) Porcentaje de solicitudes por agrupacion geografica
#
# b) Porcentaje de solicitudes por nivel de estudios
#
# c) Media de tiempo en busca de empleo
#
# d) Porcentaje de solicitudes aprobadas
#
# e) Relacion de aprobacion y rechazo de solicitudes contra los atributos geograficos
#
# f) Agrupacion de registros que compartan caracteristicas similares
#
# g) Pronostico de aprobacion basado en observaciones previas

# %%
import pandas as pd
import requests

# %%
dataset_url = "https://raw.githubusercontent.com/PosgradoMNA/actividades-del-projecto-equipo-727/main/solicitudes-seguro-de-desempleo.csv"

# %%
df_solicitudes = pd.read_csv(dataset_url)

# %%
df_solicitudes.describe(include='all')
# Out:
#           alcaldia      colonia codigo_postal     tipo_poblacion  \
# count        20767        20788         20788              20788
# unique          16         1454          1107                 51
# top     IZTAPALAPA  ZONA CENTRO      SIN DATO  POBLACION GENERAL
# freq          2898          631          1653              12711
# mean           NaN          NaN           NaN                NaN
# std            NaN          NaN           NaN                NaN
# min            NaN          NaN           NaN                NaN
# 25%            NaN          NaN           NaN                NaN
# 50%            NaN          NaN           NaN                NaN
# 75%            NaN          NaN           NaN                NaN
# max            NaN          NaN           NaN                NaN
#
#        ult_grado_estudios estatus_estudios categoria_profesion  profesion  \
# count               20202            19824                3137       3221
# ...
